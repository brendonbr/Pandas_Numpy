# %%
import pandas as pd
import numpy as np
import requests

# %%
# replace the "demo" apikey below with your own key from https://www.alphavantage.co/support/#api-key
url = 'https://www.alphavantage.co/query?function=TIME_SERIES_DAILY_ADJUSTED&symbol=Apple&apikey=NU4NO20AUWFS6VMK'
r = requests.get(url)
data = r.json()

print(data)
# Out:
# {'Error Message': 'Invalid API call. Please retry or visit the documentation (https://www.alphavantage.co/documentation/) for TIME_SERIES_DAILY_ADJUSTED.'}

# %%
df=pd.read_csv("arq.csv")

# %%
df
# Out:
#           data  aberto      alta   baixa  fechado  ajuste fechado   volume  \
# 0   2023-02-23  131.50  131.7000  128.86   130.79      130.790000  3723328
# 1   2023-02-22  131.90  131.9900  130.29   130.97      130.970000  3200185
# 2   2023-02-21  134.00  134.3850  131.66   131.71      131.710000  4257210
# 3   2023-02-17  134.50  135.5800  133.89   135.02      135.020000  3466184
# 4   2023-02-16  135.57  135.9672  134.59   135.00      135.000000  2965495
# ..         ...     ...       ...     ...      ...             ...      ...
# 95  2022-10-06  124.88  125.3000  121.77   122.23      119.307653  5074624
# 96  2022-10-05  124.71  126.4600  124.23   125.74      122.733734  3212872
# 97  2022-10-04  122.80  125.6500  122.52   125.50      122.499472  4566055
# 98  2022-10-03  120.16  122.2100  119.60   121.51      118.604867  4261729
# 99  2022-09-30  121.66  122.4300  118.61   118.81      115.969420  5346108
#
#     quantia de dividendos  coeficiente de divisão
# ...

# %%
df2=pd.read_excel('data/1817.xls',sheet_name='T 1817_1')

# %%
df2
# Out:
#                                              DATA.RIO        Unnamed: 1  \
# 0                                                 NaN               NaN
# 1   Tabela 1817 - Ensino fundamental - Número de e...               NaN
# 2                                                 NaN               NaN
# 3                          Dependência Administrativa  Total de Escolas
# 4                                                 NaN               NaN
# 5                                                2000               NaN
# 6                                             Federal                13
# 7                                            Estadual               136
# 8                                           Municipal               953
# 9                                          Particular              1284
# 10                                               2001               NaN
# 11                                            Federal                13
# ...

# %%
df2.rename(columns={"DATA.RIO":"Dependência Administrativa"},inplace=True)

# %%
df2.rename(columns={"Unnamed: 1":"Total de Escolas"},inplace=True)

# %%
df2.rename(columns={"Unnamed: 2":"Escolas com Água"},inplace=True)

# %%
df2.rename(columns={"Unnamed: 3":"Escolas com Energia Elétrica"},inplace=True)

# %%
df2.rename(columns={"Unnamed: 4":"Escolas com Esgoto"},inplace=True)

# %%
df_filtrado=df2.drop(index=[0,1,2,3,4,40,41,42]).reset_index(drop=True)

# %%
df_filtrado
# Out:
#    Dependência Administrativa Total de Escolas Escolas com Água  \
# 0                        2000              NaN              NaN
# 1                     Federal               13               13
# 2                    Estadual              136              136
# 3                   Municipal              953              953
# 4                  Particular             1284             1284
# 5                        2001              NaN              NaN
# 6                     Federal               13               13
# 7                    Estadual              123              123
# 8                   Municipal              950              950
# 9                  Particular             1330             1329
# 10                       2002              NaN              NaN
# 11                    Federal               13               13
# 12                   Estadual              117              117
# 13                  Municipal              962              962
# ...

# %%
df2_2000=df_filtrado.loc[1:4]
df2_2001=df_filtrado.loc[6:9]
df2_2002=df_filtrado.loc[11:14]
df2_2003=df_filtrado.loc[16:19]
df2_2004=df_filtrado.loc[21:24]
df2_2005=df_filtrado.loc[26:29]
df2_2006=df_filtrado.loc[31:34]

# %%
df2_2000
# Out:
#   Dependência Administrativa Total de Escolas Escolas com Água  \
# 1                    Federal               13               13
# 2                   Estadual              136              136
# 3                  Municipal              953              953
# 4                 Particular             1284             1284
#
#   Escolas com Energia Elétrica Escolas com Esgoto
# 1                           13                 13
# 2                          136                136
# 3                          953                950
# 4                         1284               1282

# %%
df_2000_1=np.array([],[],[],[])

# %%
df2_2001
# Out:
#   Dependência Administrativa Total de Escolas Escolas com Água  \
# 6                    Federal               13               13
# 7                   Estadual              123              123
# 8                  Municipal              950              950
# 9                 Particular             1330             1329
#
#   Escolas com Energia Elétrica Escolas com Esgoto
# 6                           13                 13
# 7                          123                123
# 8                          950                946
# 9                         1330               1328

# %%
df2_2002
# Out:
#    Dependência Administrativa Total de Escolas Escolas com Água  \
# 11                    Federal               13               13
# 12                   Estadual              117              117
# 13                  Municipal              962              962
# 14                 Particular             1248             1247
#
#    Escolas com Energia Elétrica Escolas com Esgoto
# 11                           13                 13
# 12                          117                117
# 13                          962                960
# 14                         1248               1248

# %%
df2_2003
# Out:
#    Dependência Administrativa Total de Escolas Escolas com Água  \
# 16                    Federal               13               13
# 17                   Estadual              116              116
# 18                  Municipal              965              965
# 19                 Particular             1278             1278
#
#    Escolas com Energia Elétrica Escolas com Esgoto
# 16                           13                 13
# 17                          116                116
# 18                          965                964
# 19                         1278               1277

# %%
df2_2004
# Out:
#    Dependência Administrativa Total de Escolas Escolas com Água  \
# 21                    Federal               13               13
# 22                   Estadual              113              113
# 23                  Municipal              973              972
# 24                 Particular             1157             1157
#
#    Escolas com Energia Elétrica Escolas com Esgoto
# 21                           13                 13
# 22                          113                113
# 23                          973                971
# 24                         1157               1155

# %%
df2_2005
# Out:
#    Dependência Administrativa Total de Escolas Escolas com Água  \
# 26                    Federal               13               13
# 27                   Estadual              110              110
# 28                  Municipal              977              977
# 29                 Particular             1113             1113
#
#    Escolas com Energia Elétrica Escolas com Esgoto
# 26                           13                 13
# 27                          110                110
# 28                          977                977
# 29                         1113               1113

# %%
df2_2006
# Out:
#    Dependência Administrativa Total de Escolas Escolas com Água  \
# 31                    Federal               13               13
# 32                   Estadual               99               99
# 33                  Municipal              980              978
# 34                 Particular             1009             1007
#
#    Escolas com Energia Elétrica Escolas com Esgoto
# 31                           13                 13
# 32                           99                 99
# 33                          980                980
# 34                         1009               1008

# %%
df3=pd.read_excel('data/1817.xls',sheet_name='T 1817_2')

# %%
df3
# Out:
#                                              DATA.RIO        Unnamed: 1  \
# 0                                                 NaN               NaN
# 1   Tabela 1817 - Ensino fundamental - Número de e...               NaN
# 2                                                 NaN               NaN
# 3                          Dependência Administrativa  Total de Escolas
# 4                                                 NaN               NaN
# 5                                                2007               NaN
# 6                                             Federal                15
# 7                                            Estadual                89
# 8                                           Municipal               997
# 9                                          Particular               649
# 10                                               2008               NaN
# 11                                            Federal                15
# ...

# %%
df3.rename(columns={"DATA.RIO":"Dependência Administrativa"},inplace=True)

# %%
df3.rename(columns={"Unnamed: 1":"Total de Escolas"},inplace=True)

# %%
df3.rename(columns={"Unnamed: 2":"Escolas com Água"},inplace=True)

# %%
df3.rename(columns={"Unnamed: 3":"Escolas com Energia Elétrica"},inplace=True)

# %%
df3.rename(columns={"Unnamed: 4":"Escolas com Esgoto"},inplace=True)

# %%
df_filtrado_2=df3.drop(index=[0,1,2,3,4,40,41,42]).reset_index(drop=True)

# %%
df_filtrado_2
# Out:
#    Dependência Administrativa Total de Escolas Escolas com Água  \
# 0                        2007              NaN              NaN
# 1                     Federal               15               15
# 2                    Estadual               89               89
# 3                   Municipal              997              996
# 4                  Particular              649              646
# 5                        2008              NaN              NaN
# 6                     Federal               15               15
# 7                    Estadual               84               84
# 8                   Municipal              993              940
# 9                  Particular             1107             1092
# 10                       2009              NaN              NaN
# 11                    Federal               15               15
# 12                   Estadual               77               77
# 13                  Municipal             1024              977
# ...

# %%
df2_2007=df_filtrado_2.loc[1:4]
df2_2008=df_filtrado_2.loc[6:9]
df2_2009=df_filtrado_2.loc[11:14]
df2_2010=df_filtrado_2.loc[16:19]
df2_2011=df_filtrado_2.loc[21:24]
df2_2012=df_filtrado_2.loc[26:29]
df2_2013=df_filtrado_2.loc[31:34]

# %%
df2_2007
# Out:
#   Dependência Administrativa Total de Escolas Escolas com Água  \
# 1                    Federal               15               15
# 2                   Estadual               89               89
# 3                  Municipal              997              996
# 4                 Particular              649              646
#
#   Escolas com Energia Elétrica Escolas com Esgoto
# 1                           15                 15
# 2                           89                 89
# 3                          997                997
# 4                          649                649

# %%
df2_2008
# Out:
#   Dependência Administrativa Total de Escolas Escolas com Água  \
# 6                    Federal               15               15
# 7                   Estadual               84               84
# 8                  Municipal              993              940
# 9                 Particular             1107             1092
#
#   Escolas com Energia Elétrica Escolas com Esgoto
# 6                           15                 15
# 7                           84                 84
# 8                          993                993
# 9                         1107               1107

# %%
df2_2009
# Out:
#    Dependência Administrativa Total de Escolas Escolas com Água  \
# 11                    Federal               15               15
# 12                   Estadual               77               77
# 13                  Municipal             1024              977
# 14                 Particular             1056             1045
#
#    Escolas com Energia Elétrica Escolas com Esgoto
# 11                           15                 15
# 12                           77                 77
# 13                         1024               1024
# 14                         1056               1056

# %%
df2_2010
# Out:
#    Dependência Administrativa Total de Escolas Escolas com Água  \
# 16                    Federal               17               17
# 17                   Estadual               72               72
# 18                  Municipal              985              985
# 19                 Particular             1156             1149
#
#    Escolas com Energia Elétrica Escolas com Esgoto
# 16                           17                 17
# 17                           72                 72
# 18                          985                985
# 19                         1156               1156

# %%
df2_2011
# Out:
#    Dependência Administrativa Total de Escolas Escolas com Água  \
# 21                    Federal               17               17
# 22                   Estadual               64               64
# 23                  Municipal              982              982
# 24                 Particular             1268             1259
#
#    Escolas com Energia Elétrica Escolas com Esgoto
# 21                           17                 17
# 22                           64                 64
# 23                          982                982
# 24                         1268               1268

# %%
df2_2012
# Out:
#    Dependência Administrativa Total de Escolas Escolas com Água  \
# 26                    Federal               17               17
# 27                   Estadual               56               56
# 28                  Municipal              994              994
# 29                 Particular             1271             1268
#
#    Escolas com Energia Elétrica Escolas com Esgoto
# 26                           17                 17
# 27                           56                 56
# 28                          994                994
# 29                         1270               1270

# %%
df2_2013
# Out:
#    Dependência Administrativa Total de Escolas Escolas com Água  \
# 31                    Federal               17               17
# 32                   Estadual               53               53
# 33                  Municipal              993              993
# 34                 Particular             1397             1395
#
#    Escolas com Energia Elétrica Escolas com Esgoto
# 31                           17                 17
# 32                           53                 53
# 33                          993                993
# 34                         1397               1397

# %%
df4=pd.read_excel('data/1817.xls',sheet_name='T 1817_3')

# %%
df4
# Out:
#                                              DATA.RIO        Unnamed: 1  \
# 0                                                 NaN               NaN
# 1   Tabela 1817 - Ensino fundamental - Número de e...               NaN
# 2                                                 NaN               NaN
# 3                          Dependência Administrativa  Total de Escolas
# 4                                                 NaN               NaN
# 5                                                2014               NaN
# 6                                             Federal                17
# 7                                            Estadual                45
# 8                                           Municipal               996
# 9                                          Particular              1352
# 10                                               2015               NaN
# 11                                            Federal                17
# ...

# %%
df4.rename(columns={"DATA.RIO":"Dependência Administrativa"},inplace=True)

# %%
df4.rename(columns={"Unnamed: 1":"Total de Escolas"},inplace=True)

# %%
df4.rename(columns={"Unnamed: 2":"Escolas com Água"},inplace=True)

# %%
df4.rename(columns={"Unnamed: 3":"Escolas com Energia Elétrica"},inplace=True)

# %%
df4.rename(columns={"Unnamed: 4":"Escolas com Esgoto"},inplace=True)

# %%
df_filtrado_3=df4.drop(index=[0,1,2,3,4,40,41,42]).reset_index(drop=True)

# %%
df_filtrado_3
# Out:
#    Dependência Administrativa Total de Escolas Escolas com Água  \
# 0                        2014              NaN              NaN
# 1                     Federal               17               17
# 2                    Estadual               45               45
# 3                   Municipal              996              996
# 4                  Particular             1352             1350
# 5                        2015              NaN              NaN
# 6                     Federal               17               17
# 7                    Estadual               12               12
# 8                   Municipal              991              991
# 9                  Particular             1246             1241
# 10                       2016              NaN              NaN
# 11                    Federal               17               17
# 12                   Estadual               11               11
# 13                  Municipal             1000             1000
# ...

# %%
df2_2014=df_filtrado_3.loc[1:4]
df2_2015=df_filtrado_3.loc[6:9]
df2_2016=df_filtrado_3.loc[11:14]
df2_2017=df_filtrado_3.loc[16:19]
df2_2018=df_filtrado_3.loc[21:24]
df2_2019=df_filtrado_3.loc[26:29]
df2_2020=df_filtrado_3.loc[31:34]

# %%
df2_2014
# Out:
#   Dependência Administrativa Total de Escolas Escolas com Água  \
# 1                    Federal               17               17
# 2                   Estadual               45               45
# 3                  Municipal              996              996
# 4                 Particular             1352             1350
#
#   Escolas com Energia Elétrica Escolas com Esgoto
# 1                           17                 17
# 2                           45                 45
# 3                          996                996
# 4                         1352               1352

# %%
df2_2015
# Out:
#   Dependência Administrativa Total de Escolas Escolas com Água  \
# 6                    Federal               17               17
# 7                   Estadual               12               12
# 8                  Municipal              991              991
# 9                 Particular             1246             1241
#
#   Escolas com Energia Elétrica Escolas com Esgoto
# 6                           17                 17
# 7                           12                 12
# 8                          991                991
# 9                         1246               1246

# %%
df2_2016
# Out:
#    Dependência Administrativa Total de Escolas Escolas com Água  \
# 11                    Federal               17               17
# 12                   Estadual               11               11
# 13                  Municipal             1000             1000
# 14                 Particular             1239             1236
#
#    Escolas com Energia Elétrica Escolas com Esgoto
# 11                           17                 17
# 12                           11                 11
# 13                         1000               1000
# 14                         1239               1239

# %%
df2_2017
# Out:
#    Dependência Administrativa Total de Escolas Escolas com Água  \
# 16                    Federal               17               17
# 17                   Estadual               10               10
# 18                  Municipal             1007             1007
# 19                 Particular             1251             1247
#
#    Escolas com Energia Elétrica Escolas com Esgoto
# 16                           17                 17
# 17                           10                 10
# 18                         1007               1007
# 19                         1251               1251

# %%
df2_2018
# Out:
#    Dependência Administrativa Total de Escolas Escolas com Água  \
# 21                    Federal               15               15
# 22                   Estadual                9                9
# 23                  Municipal              992              992
# 24                 Particular             1268             1263
#
#    Escolas com Energia Elétrica Escolas com Esgoto
# 21                           15                 15
# 22                            9                  9
# 23                          992                992
# 24                         1268               1268

# %%
df2_2019
# Out:
#    Dependência Administrativa Total de Escolas Escolas com Água  \
# 26                    Federal               16               16
# 27                   Estadual                9                9
# 28                  Municipal              992              992
# 29                 Particular             1268             1260
#
#    Escolas com Energia Elétrica Escolas com Esgoto
# 26                           16                 16
# 27                            9                  9
# 28                          992                992
# 29                         1268               1267

# %%
df2_2020
# Out:
#    Dependência Administrativa Total de Escolas Escolas com Água  \
# 31                    Federal               15               15
# 32                   Estadual                8                8
# 33                  Municipal              991              991
# 34                 Particular             1235             1225
#
#    Escolas com Energia Elétrica Escolas com Esgoto
# 31                           15                 15
# 32                            8                  8
# 33                          991                991
# 34                         1235               1234

# %%
df5=pd.read_excel('data/1817.xls',sheet_name='T 1817_4')

# %%
df5
# Out:
#                                              DATA.RIO        Unnamed: 1  \
# 0                                                 NaN               NaN
# 1   Tabela 1817 - Ensino fundamental - Número de e...               NaN
# 2                                                 NaN               NaN
# 3                          Dependência Administrativa  Total de Escolas
# 4                                                 NaN               NaN
# 5                                                2021               NaN
# 6                                             Federal                17
# 7                                            Estadual                 9
# 8                                           Municipal              1005
# 9                                          Particular              1258
# 10                                               2022               NaN
# 11                                            Federal                17
# ...

# %%
df5.rename(columns={"DATA.RIO":"Dependência Administrativa"},inplace=True)

# %%
df5.rename(columns={"Unnamed: 1":"Total de Escolas"},inplace=True)

# %%
df5.rename(columns={"Unnamed: 2":"Escolas com Água"},inplace=True)

# %%
df5.rename(columns={"Unnamed: 3":"Escolas com Energia Elétrica"},inplace=True)

# %%
df5.rename(columns={"Unnamed: 4":"Escolas com Esgoto"},inplace=True)

# %%
df_filtrado_4=df5.drop(index=[0,1,2,3,4,15,16,17]).reset_index(drop=True)

# %%
df_filtrado_4
# Out:
#   Dependência Administrativa Total de Escolas Escolas com Água  \
# 0                       2021              NaN              NaN
# 1                    Federal               17               17
# 2                   Estadual                9                9
# 3                  Municipal             1005             1005
# 4                 Particular             1258             1247
# 5                       2022              NaN              NaN
# 6                    Federal               17               17
# 7                   Estadual                9                9
# 8                  Municipal             1005             1005
# 9                 Particular             1270             1261
#
#   Escolas com Energia Elétrica Escolas com Esgoto
# 0                          NaN                NaN
# 1                           17                 17
# 2                            9                  9
# 3                         1005               1005
# ...

# %%
df2_2021=df_filtrado_4.loc[1:4]
df2_2022=df_filtrado_4.loc[6:9]

# %%
df2_2021
# Out:
#   Dependência Administrativa Total de Escolas Escolas com Água  \
# 1                    Federal               17               17
# 2                   Estadual                9                9
# 3                  Municipal             1005             1005
# 4                 Particular             1258             1247
#
#   Escolas com Energia Elétrica Escolas com Esgoto
# 1                           17                 17
# 2                            9                  9
# 3                         1005               1005
# 4                         1258               1256

# %%
df2_2022
# Out:
#   Dependência Administrativa Total de Escolas Escolas com Água  \
# 6                    Federal               17               17
# 7                   Estadual                9                9
# 8                  Municipal             1005             1005
# 9                 Particular             1270             1261
#
#   Escolas com Energia Elétrica Escolas com Esgoto
# 6                           17                 17
# 7                            9                  9
# 8                         1005               1005
# 9                         1270               1268
