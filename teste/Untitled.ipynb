# %%
import pandas as pd
import numpy as np
import requests

# %% [raw]
# # replace the "demo" apikey below with your own key from https://www.alphavantage.co/support/#api-key
# url = 'https://www.alphavantage.co/query?function=TIME_SERIES_DAILY_ADJUSTED&symbol=Apple&apikey=NU4NO20AUWFS6VMK'
# r = requests.get(url)
# data = r.json()
#
# print(data)

# %%
df=pd.read_csv("arq.csv")

# %%
df
# Out:
#           data  aberto      alta   baixa  fechado  ajuste fechado   volume  \
# 0   2023-02-23  131.50  131.7000  128.86   130.79      130.790000  3723328
# 1   2023-02-22  131.90  131.9900  130.29   130.97      130.970000  3200185
# 2   2023-02-21  134.00  134.3850  131.66   131.71      131.710000  4257210
# 3   2023-02-17  134.50  135.5800  133.89   135.02      135.020000  3466184
# 4   2023-02-16  135.57  135.9672  134.59   135.00      135.000000  2965495
# ..         ...     ...       ...     ...      ...             ...      ...
# 95  2022-10-06  124.88  125.3000  121.77   122.23      119.307653  5074624
# 96  2022-10-05  124.71  126.4600  124.23   125.74      122.733734  3212872
# 97  2022-10-04  122.80  125.6500  122.52   125.50      122.499472  4566055
# 98  2022-10-03  120.16  122.2100  119.60   121.51      118.604867  4261729
# 99  2022-09-30  121.66  122.4300  118.61   118.81      115.969420  5346108
#
#     quantia de dividendos  coeficiente de divisão
# ...

# %%
df_2=pd.read_excel('data/1817.xls',sheet_name='T 1817_1')

# %%
df_2
# Out:
#                                              DATA.RIO        Unnamed: 1  \
# 0                                                 NaN               NaN
# 1   Tabela 1817 - Ensino fundamental - Número de e...               NaN
# 2                                                 NaN               NaN
# 3                          Dependência Administrativa  Total de Escolas
# 4                                                 NaN               NaN
# 5                                                2000               NaN
# 6                                             Federal                13
# 7                                            Estadual               136
# 8                                           Municipal               953
# 9                                          Particular              1284
# 10                                               2001               NaN
# 11                                            Federal                13
# ...

# %%
df_2.rename(columns={"DATA.RIO":"Dependência Administrativa"},inplace=True)

# %%
df_2.rename(columns={"Unnamed: 1":"Total de Escolas"},inplace=True)

# %%
df_2.rename(columns={"Unnamed: 2":"Escolas com Água"},inplace=True)

# %%
df_2.rename(columns={"Unnamed: 3":"Escolas com Energia Elétrica"},inplace=True)

# %%
df_2.rename(columns={"Unnamed: 4":"Escolas com Esgoto"},inplace=True)

# %%
df_filtrado=df_2.drop(index=[0,1,2,3,4,40,41,42]).reset_index(drop=True)

# %%
df_filtrado
# Out:
#    Dependência Administrativa Total de Escolas Escolas com Água  \
# 0                        2000              NaN              NaN
# 1                     Federal               13               13
# 2                    Estadual              136              136
# 3                   Municipal              953              953
# 4                  Particular             1284             1284
# 5                        2001              NaN              NaN
# 6                     Federal               13               13
# 7                    Estadual              123              123
# 8                   Municipal              950              950
# 9                  Particular             1330             1329
# 10                       2002              NaN              NaN
# 11                    Federal               13               13
# 12                   Estadual              117              117
# 13                  Municipal              962              962
# ...

# %%
df_2000=df_filtrado.loc[1:4]
df_2001=df_filtrado.loc[6:9]
df_2002=df_filtrado.loc[11:14]
df_2003=df_filtrado.loc[16:19]
df_2004=df_filtrado.loc[21:24]
df_2005=df_filtrado.loc[26:29]
df_2006=df_filtrado.loc[31:34]

# %%
df_2000.reset_index(drop=True)
# Out:
#   Dependência Administrativa Total de Escolas Escolas com Água  \
# 0                    Federal               13               13
# 1                   Estadual              136              136
# 2                  Municipal              953              953
# 3                 Particular             1284             1284
#
#   Escolas com Energia Elétrica Escolas com Esgoto
# 0                           13                 13
# 1                          136                136
# 2                          953                950
# 3                         1284               1282

# %%
df_2000_1=np.array(
                        [
                            [
                                df_2000.iloc[0]['Total de Escolas'],
                                df_2000.iloc[0]['Escolas com Água'],
                                df_2000.iloc[0]['Escolas com Energia Elétrica'],
                                df_2000.iloc[0]['Escolas com Esgoto']
                            ],
                            [
                                df_2000.iloc[1]['Total de Escolas'],
                                df_2000.iloc[1]['Escolas com Água'],
                                df_2000.iloc[1]['Escolas com Energia Elétrica'],
                                df_2000.iloc[1]['Escolas com Esgoto']
                            ],
                            [
                                df_2000.iloc[2]['Total de Escolas'],
                                df_2000.iloc[2]['Escolas com Água'],
                                df_2000.iloc[2]['Escolas com Energia Elétrica'],
                                df_2000.iloc[2]['Escolas com Esgoto']
                            ],
                            [
                                df_2000.iloc[3]['Total de Escolas'],
                                df_2000.iloc[3]['Escolas com Água'],
                                df_2000.iloc[3]['Escolas com Energia Elétrica'],
                                df_2000.iloc[3]['Escolas com Esgoto']
                            ]
                        ]
                    )

# %%
df_2000_1

# %%
df_2001.reset_index(drop=True)

# %%
df_2001_1=np.array(
                        [
                            [
                                df_2001.iloc[0]['Total de Escolas'],
                                df_2001.iloc[0]['Escolas com Água'],
                                df_2001.iloc[0]['Escolas com Energia Elétrica'],
                                df_2001.iloc[0]['Escolas com Esgoto']
                            ],
                            [
                                df_2001.iloc[1]['Total de Escolas'],
                                df_2001.iloc[1]['Escolas com Água'],
                                df_2001.iloc[1]['Escolas com Energia Elétrica'],
                                df_2001.iloc[1]['Escolas com Esgoto']
                            ],
                            [
                                df_2001.iloc[2]['Total de Escolas'],
                                df_2001.iloc[2]['Escolas com Água'],
                                df_2001.iloc[2]['Escolas com Energia Elétrica'],
                                df_2001.iloc[2]['Escolas com Esgoto']
                            ],
                            [
                                df_2001.iloc[3]['Total de Escolas'],
                                df_2001.iloc[3]['Escolas com Água'],
                                df_2001.iloc[3]['Escolas com Energia Elétrica'],
                                df_2001.iloc[3]['Escolas com Esgoto']
                            ]
                        ]
                    )

# %%
df_2001_1
# Out:
# array([[  13,   13,   13,   13],
#        [ 123,  123,  123,  123],
#        [ 950,  950,  950,  946],
#        [1330, 1329, 1330, 1328]])

# %%
df_2002.reset_index(drop=True)
# Out:
#   Dependência Administrativa Total de Escolas Escolas com Água  \
# 0                    Federal               13               13
# 1                   Estadual              117              117
# 2                  Municipal              962              962
# 3                 Particular             1248             1247
#
#   Escolas com Energia Elétrica Escolas com Esgoto
# 0                           13                 13
# 1                          117                117
# 2                          962                960
# 3                         1248               1248

# %%
df_2002_1=np.array(
                        [
                            [
                                df_2002.iloc[0]['Total de Escolas'],
                                df_2002.iloc[0]['Escolas com Água'],
                                df_2002.iloc[0]['Escolas com Energia Elétrica'],
                                df_2002.iloc[0]['Escolas com Esgoto']
                            ],
                            [
                                df_2002.iloc[1]['Total de Escolas'],
                                df_2002.iloc[1]['Escolas com Água'],
                                df_2002.iloc[1]['Escolas com Energia Elétrica'],
                                df_2002.iloc[1]['Escolas com Esgoto']
                            ],
                            [
                                df_2002.iloc[2]['Total de Escolas'],
                                df_2002.iloc[2]['Escolas com Água'],
                                df_2002.iloc[2]['Escolas com Energia Elétrica'],
                                df_2002.iloc[2]['Escolas com Esgoto']
                            ],
                            [
                                df_2002.iloc[3]['Total de Escolas'],
                                df_2002.iloc[3]['Escolas com Água'],
                                df_2002.iloc[3]['Escolas com Energia Elétrica'],
                                df_2002.iloc[3]['Escolas com Esgoto']
                            ]
                        ]
                    )

# %%
df_2002_1
# Out:
# array([[  13,   13,   13,   13],
#        [ 117,  117,  117,  117],
#        [ 962,  962,  962,  960],
#        [1248, 1247, 1248, 1248]])

# %%
df_2003.reset_index(drop=True)
# Out:
#   Dependência Administrativa Total de Escolas Escolas com Água  \
# 0                    Federal               13               13
# 1                   Estadual              116              116
# 2                  Municipal              965              965
# 3                 Particular             1278             1278
#
#   Escolas com Energia Elétrica Escolas com Esgoto
# 0                           13                 13
# 1                          116                116
# 2                          965                964
# 3                         1278               1277

# %%
df_2003_1=np.array(
                        [
                            [
                                df_2003.iloc[0]['Total de Escolas'],
                                df_2003.iloc[0]['Escolas com Água'],
                                df_2003.iloc[0]['Escolas com Energia Elétrica'],
                                df_2003.iloc[0]['Escolas com Esgoto']
                            ],
                            [
                                df_2003.iloc[1]['Total de Escolas'],
                                df_2003.iloc[1]['Escolas com Água'],
                                df_2003.iloc[1]['Escolas com Energia Elétrica'],
                                df_2003.iloc[1]['Escolas com Esgoto']
                            ],
                            [
                                df_2003.iloc[2]['Total de Escolas'],
                                df_2003.iloc[2]['Escolas com Água'],
                                df_2003.iloc[2]['Escolas com Energia Elétrica'],
                                df_2003.iloc[2]['Escolas com Esgoto']
                            ],
                            [
                                df_2003.iloc[3]['Total de Escolas'],
                                df_2003.iloc[3]['Escolas com Água'],
                                df_2003.iloc[3]['Escolas com Energia Elétrica'],
                                df_2003.iloc[3]['Escolas com Esgoto']
                            ]
                        ]
                    )

# %%
df_2003_1
# Out:
# array([[  13,   13,   13,   13],
#        [ 116,  116,  116,  116],
#        [ 965,  965,  965,  964],
#        [1278, 1278, 1278, 1277]])

# %%
df_2004.reset_index(drop=True)
# Out:
#   Dependência Administrativa Total de Escolas Escolas com Água  \
# 0                    Federal               13               13
# 1                   Estadual              113              113
# 2                  Municipal              973              972
# 3                 Particular             1157             1157
#
#   Escolas com Energia Elétrica Escolas com Esgoto
# 0                           13                 13
# 1                          113                113
# 2                          973                971
# 3                         1157               1155

# %%
df_2004_1=np.array(
                        [
                            [
                                df_2004.iloc[0]['Total de Escolas'],
                                df_2004.iloc[0]['Escolas com Água'],
                                df_2004.iloc[0]['Escolas com Energia Elétrica'],
                                df_2004.iloc[0]['Escolas com Esgoto']
                            ],
                            [
                                df_2004.iloc[1]['Total de Escolas'],
                                df_2004.iloc[1]['Escolas com Água'],
                                df_2004.iloc[1]['Escolas com Energia Elétrica'],
                                df_2004.iloc[1]['Escolas com Esgoto']
                            ],
                            [
                                df_2004.iloc[2]['Total de Escolas'],
                                df_2004.iloc[2]['Escolas com Água'],
                                df_2004.iloc[2]['Escolas com Energia Elétrica'],
                                df_2004.iloc[2]['Escolas com Esgoto']
                            ],
                            [
                                df_2004.iloc[3]['Total de Escolas'],
                                df_2004.iloc[3]['Escolas com Água'],
                                df_2004.iloc[3]['Escolas com Energia Elétrica'],
                                df_2004.iloc[3]['Escolas com Esgoto']
                            ]
                        ]
                    )

# %%
df_2004_1
# Out:
# array([[  13,   13,   13,   13],
#        [ 113,  113,  113,  113],
#        [ 973,  972,  973,  971],
#        [1157, 1157, 1157, 1155]])

# %%
df_2005.reset_index(drop=True)

# %%
df_2005_1=np.array(
                        [
                            [
                                df_2005.iloc[0]['Total de Escolas'],
                                df_2005.iloc[0]['Escolas com Água'],
                                df_2005.iloc[0]['Escolas com Energia Elétrica'],
                                df_2005.iloc[0]['Escolas com Esgoto']
                            ],
                            [
                                df_2005.iloc[1]['Total de Escolas'],
                                df_2005.iloc[1]['Escolas com Água'],
                                df_2005.iloc[1]['Escolas com Energia Elétrica'],
                                df_2005.iloc[1]['Escolas com Esgoto']
                            ],
                            [
                                df_2005.iloc[2]['Total de Escolas'],
                                df_2005.iloc[2]['Escolas com Água'],
                                df_2005.iloc[2]['Escolas com Energia Elétrica'],
                                df_2005.iloc[2]['Escolas com Esgoto']
                            ],
                            [
                                df_2005.iloc[3]['Total de Escolas'],
                                df_2005.iloc[3]['Escolas com Água'],
                                df_2005.iloc[3]['Escolas com Energia Elétrica'],
                                df_2005.iloc[3]['Escolas com Esgoto']
                            ]
                        ]
                    )

# %%
df_2005_1
# Out:
# array([[  13,   13,   13,   13],
#        [ 110,  110,  110,  110],
#        [ 977,  977,  977,  977],
#        [1113, 1113, 1113, 1113]])

# %%
df_2006.reset_index(drop=True)
# Out:
#   Dependência Administrativa Total de Escolas Escolas com Água  \
# 0                    Federal               13               13
# 1                   Estadual               99               99
# 2                  Municipal              980              978
# 3                 Particular             1009             1007
#
#   Escolas com Energia Elétrica Escolas com Esgoto
# 0                           13                 13
# 1                           99                 99
# 2                          980                980
# 3                         1009               1008

# %%
df_2006_1=np.array(
                        [
                            [
                                df_2006.iloc[0]['Total de Escolas'],
                                df_2006.iloc[0]['Escolas com Água'],
                                df_2006.iloc[0]['Escolas com Energia Elétrica'],
                                df_2006.iloc[0]['Escolas com Esgoto']
                            ],
                            [
                                df_2006.iloc[1]['Total de Escolas'],
                                df_2006.iloc[1]['Escolas com Água'],
                                df_2006.iloc[1]['Escolas com Energia Elétrica'],
                                df_2006.iloc[1]['Escolas com Esgoto']
                            ],
                            [
                                df_2006.iloc[2]['Total de Escolas'],
                                df_2006.iloc[2]['Escolas com Água'],
                                df_2006.iloc[2]['Escolas com Energia Elétrica'],
                                df_2006.iloc[2]['Escolas com Esgoto']
                            ],
                            [
                                df_2006.iloc[3]['Total de Escolas'],
                                df_2006.iloc[3]['Escolas com Água'],
                                df_2006.iloc[3]['Escolas com Energia Elétrica'],
                                df_2006.iloc[3]['Escolas com Esgoto']
                            ]
                        ]
                    )

# %%
df_2006_1
# Out:
# array([[  13,   13,   13,   13],
#        [  99,   99,   99,   99],
#        [ 980,  978,  980,  980],
#        [1009, 1007, 1009, 1008]])

# %%
df_3=pd.read_excel('data/1817.xls',sheet_name='T 1817_2')

# %%
df_3
# Out:
#                                              DATA.RIO        Unnamed: 1  \
# 0                                                 NaN               NaN
# 1   Tabela 1817 - Ensino fundamental - Número de e...               NaN
# 2                                                 NaN               NaN
# 3                          Dependência Administrativa  Total de Escolas
# 4                                                 NaN               NaN
# 5                                                2007               NaN
# 6                                             Federal                15
# 7                                            Estadual                89
# 8                                           Municipal               997
# 9                                          Particular               649
# 10                                               2008               NaN
# 11                                            Federal                15
# ...

# %%
df_3.rename(columns={"DATA.RIO":"Dependência Administrativa"},inplace=True)

# %%
df_3.rename(columns={"Unnamed: 1":"Total de Escolas"},inplace=True)

# %%
df_3.rename(columns={"Unnamed: 2":"Escolas com Água"},inplace=True)

# %%
df_3.rename(columns={"Unnamed: 3":"Escolas com Energia Elétrica"},inplace=True)

# %%
df_3.rename(columns={"Unnamed: 4":"Escolas com Esgoto"},inplace=True)

# %%
df_filtrado_2=df_3.drop(index=[0,1,2,3,4,40,41,42]).reset_index(drop=True)

# %%
df_filtrado_2
# Out:
#    Dependência Administrativa Total de Escolas Escolas com Água  \
# 0                        2007              NaN              NaN
# 1                     Federal               15               15
# 2                    Estadual               89               89
# 3                   Municipal              997              996
# 4                  Particular              649              646
# 5                        2008              NaN              NaN
# 6                     Federal               15               15
# 7                    Estadual               84               84
# 8                   Municipal              993              940
# 9                  Particular             1107             1092
# 10                       2009              NaN              NaN
# 11                    Federal               15               15
# 12                   Estadual               77               77
# 13                  Municipal             1024              977
# ...

# %%
df_2007=df_filtrado_2.loc[1:4]
df_2008=df_filtrado_2.loc[6:9]
df_2009=df_filtrado_2.loc[11:14]
df_2010=df_filtrado_2.loc[16:19]
df_2011=df_filtrado_2.loc[21:24]
df_2012=df_filtrado_2.loc[26:29]
df_2013=df_filtrado_2.loc[31:34]

# %%
df_2007.reset_index(drop=True)
# Out:
#   Dependência Administrativa Total de Escolas Escolas com Água  \
# 0                    Federal               15               15
# 1                   Estadual               89               89
# 2                  Municipal              997              996
# 3                 Particular              649              646
#
#   Escolas com Energia Elétrica Escolas com Esgoto
# 0                           15                 15
# 1                           89                 89
# 2                          997                997
# 3                          649                649

# %%
df_2007_1=np.array(
                        [
                            [
                                df_2007.iloc[0]['Total de Escolas'],
                                df_2007.iloc[0]['Escolas com Água'],
                                df_2007.iloc[0]['Escolas com Energia Elétrica'],
                                df_2007.iloc[0]['Escolas com Esgoto']
                            ],
                            [
                                df_2007.iloc[1]['Total de Escolas'],
                                df_2007.iloc[1]['Escolas com Água'],
                                df_2007.iloc[1]['Escolas com Energia Elétrica'],
                                df_2007.iloc[1]['Escolas com Esgoto']
                            ],
                            [
                                df_2007.iloc[2]['Total de Escolas'],
                                df_2007.iloc[2]['Escolas com Água'],
                                df_2007 .iloc[2]['Escolas com Energia Elétrica'],
                                df_2007.iloc[2]['Escolas com Esgoto']
                            ],
                            [
                                df_2007.iloc[3]['Total de Escolas'],
                                df_2007.iloc[3]['Escolas com Água'],
                                df_2007.iloc[3]['Escolas com Energia Elétrica'],
                                df_2007.iloc[3]['Escolas com Esgoto']
                            ]
                        ]
                    )

# %%
df_2007_1
# Out:
# array([[ 15,  15,  15,  15],
#        [ 89,  89,  89,  89],
#        [997, 996, 997, 997],
#        [649, 646, 649, 649]])

# %%
df_2008.reset_index(drop=True)
# Out:
#   Dependência Administrativa Total de Escolas Escolas com Água  \
# 0                    Federal               15               15
# 1                   Estadual               84               84
# 2                  Municipal              993              940
# 3                 Particular             1107             1092
#
#   Escolas com Energia Elétrica Escolas com Esgoto
# 0                           15                 15
# 1                           84                 84
# 2                          993                993
# 3                         1107               1107

# %%
df_2008_1=np.array(
                        [
                            [
                                df_2008.iloc[0]['Total de Escolas'],
                                df_2008.iloc[0]['Escolas com Água'],
                                df_2008.iloc[0]['Escolas com Energia Elétrica'],
                                df_2008.iloc[0]['Escolas com Esgoto']
                            ],
                            [
                                df_2008.iloc[1]['Total de Escolas'],
                                df_2008.iloc[1]['Escolas com Água'],
                                df_2008.iloc[1]['Escolas com Energia Elétrica'],
                                df_2008.iloc[1]['Escolas com Esgoto']
                            ],
                            [
                                df_2008.iloc[2]['Total de Escolas'],
                                df_2008.iloc[2]['Escolas com Água'],
                                df_2008.iloc[2]['Escolas com Energia Elétrica'],
                                df_2008.iloc[2]['Escolas com Esgoto']
                            ],
                            [
                                df_2008.iloc[3]['Total de Escolas'],
                                df_2008.iloc[3]['Escolas com Água'],
                                df_2008.iloc[3]['Escolas com Energia Elétrica'],
                                df_2008.iloc[3]['Escolas com Esgoto']
                            ]
                        ]
                    )

# %%
df_2008_1
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[45], line 1
# ----> 1 df_2008_1
#
# NameError: name 'df_2008_1' is not defined

# %%
df_2009.reset_index(drop=True)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[46], line 1
# ----> 1 df_2009.reset_index(drop=True)
#
# NameError: name 'df_2009' is not defined

# %%
df_2009_1=np.array(
                        [
                            [
                                df_2009.iloc[0]['Total de Escolas'],
                                df_2009.iloc[0]['Escolas com Água'],
                                df_2009.iloc[0]['Escolas com Energia Elétrica'],
                                df_2009.iloc[0]['Escolas com Esgoto']
                            ],
                            [
                                df_2009.iloc[1]['Total de Escolas'],
                                df_2009.iloc[1]['Escolas com Água'],
                                df_2009.iloc[1]['Escolas com Energia Elétrica'],
                                df_2009.iloc[1]['Escolas com Esgoto']
                            ],
                            [
                                df_2009.iloc[2]['Total de Escolas'],
                                df_2009.iloc[2]['Escolas com Água'],
                                df_2009.iloc[2]['Escolas com Energia Elétrica'],
                                df_2009.iloc[2]['Escolas com Esgoto']
                            ],
                            [
                                df_2009.iloc[3]['Total de Escolas'],
                                df_2009.iloc[3]['Escolas com Água'],
                                df_2009.iloc[3]['Escolas com Energia Elétrica'],
                                df_2009.iloc[3]['Escolas com Esgoto']
                            ]
                        ]
                    )

# %%
df_2010
# Out:
#    Dependência Administrativa Total de Escolas Escolas com Água  \
# 16                    Federal               17               17
# 17                   Estadual               72               72
# 18                  Municipal              985              985
# 19                 Particular             1156             1149
#
#    Escolas com Energia Elétrica Escolas com Esgoto
# 16                           17                 17
# 17                           72                 72
# 18                          985                985
# 19                         1156               1156

# %%
df_2011.reset_index(drop=True)
# Out:
#   Dependência Administrativa Total de Escolas Escolas com Água  \
# 0                    Federal               17               17
# 1                   Estadual               64               64
# 2                  Municipal              982              982
# 3                 Particular             1268             1259
#
#   Escolas com Energia Elétrica Escolas com Esgoto
# 0                           17                 17
# 1                           64                 64
# 2                          982                982
# 3                         1268               1268

# %%
df_2012.reset_index(drop=True)
# Out:
#   Dependência Administrativa Total de Escolas Escolas com Água  \
# 0                    Federal               17               17
# 1                   Estadual               56               56
# 2                  Municipal              994              994
# 3                 Particular             1271             1268
#
#   Escolas com Energia Elétrica Escolas com Esgoto
# 0                           17                 17
# 1                           56                 56
# 2                          994                994
# 3                         1270               1270

# %%
df_2013.reset_index(drop=True)
# Out:
#   Dependência Administrativa Total de Escolas Escolas com Água  \
# 0                    Federal               17               17
# 1                   Estadual               53               53
# 2                  Municipal              993              993
# 3                 Particular             1397             1395
#
#   Escolas com Energia Elétrica Escolas com Esgoto
# 0                           17                 17
# 1                           53                 53
# 2                          993                993
# 3                         1397               1397

# %%
df_4=pd.read_excel('data/1817.xls',sheet_name='T 1817_3')

# %%
df_4
# Out:
#                                              DATA.RIO        Unnamed: 1  \
# 0                                                 NaN               NaN
# 1   Tabela 1817 - Ensino fundamental - Número de e...               NaN
# 2                                                 NaN               NaN
# 3                          Dependência Administrativa  Total de Escolas
# 4                                                 NaN               NaN
# 5                                                2014               NaN
# 6                                             Federal                17
# 7                                            Estadual                45
# 8                                           Municipal               996
# 9                                          Particular              1352
# 10                                               2015               NaN
# 11                                            Federal                17
# ...

# %%
df_4.rename(columns={"DATA.RIO":"Dependência Administrativa"},inplace=True)

# %%
df_4.rename(columns={"Unnamed: 1":"Total de Escolas"},inplace=True)

# %%
df_4.rename(columns={"Unnamed: 2":"Escolas com Água"},inplace=True)

# %%
df_4.rename(columns={"Unnamed: 3":"Escolas com Energia Elétrica"},inplace=True)

# %%
df_4.rename(columns={"Unnamed: 4":"Escolas com Esgoto"},inplace=True)

# %%
df_filtrado_3=df_4.drop(index=[0,1,2,3,4,40,41,42]).reset_index(drop=True)

# %%
df_filtrado_3
# Out:
#    Dependência Administrativa Total de Escolas Escolas com Água  \
# 0                        2014              NaN              NaN
# 1                     Federal               17               17
# 2                    Estadual               45               45
# 3                   Municipal              996              996
# 4                  Particular             1352             1350
# 5                        2015              NaN              NaN
# 6                     Federal               17               17
# 7                    Estadual               12               12
# 8                   Municipal              991              991
# 9                  Particular             1246             1241
# 10                       2016              NaN              NaN
# 11                    Federal               17               17
# 12                   Estadual               11               11
# 13                  Municipal             1000             1000
# ...

# %%
df_2014=df_filtrado_3.loc[1:4]
df_2015=df_filtrado_3.loc[6:9]
df_2016=df_filtrado_3.loc[11:14]
df_2017=df_filtrado_3.loc[16:19]
df_2018=df_filtrado_3.loc[21:24]
df_2019=df_filtrado_3.loc[26:29]
df_2020=df_filtrado_3.loc[31:34]

# %%
df_2014.reset_index(drop=True)
# Out:
#   Dependência Administrativa Total de Escolas Escolas com Água  \
# 0                    Federal               17               17
# 1                   Estadual               45               45
# 2                  Municipal              996              996
# 3                 Particular             1352             1350
#
#   Escolas com Energia Elétrica Escolas com Esgoto
# 0                           17                 17
# 1                           45                 45
# 2                          996                996
# 3                         1352               1352

# %%
df_2015.reset_index(drop=True)
# Out:
#   Dependência Administrativa Total de Escolas Escolas com Água  \
# 0                    Federal               17               17
# 1                   Estadual               12               12
# 2                  Municipal              991              991
# 3                 Particular             1246             1241
#
#   Escolas com Energia Elétrica Escolas com Esgoto
# 0                           17                 17
# 1                           12                 12
# 2                          991                991
# 3                         1246               1246

# %%
df_2016.reset_index(drop=True)
# Out:
#   Dependência Administrativa Total de Escolas Escolas com Água  \
# 0                    Federal               17               17
# 1                   Estadual               11               11
# 2                  Municipal             1000             1000
# 3                 Particular             1239             1236
#
#   Escolas com Energia Elétrica Escolas com Esgoto
# 0                           17                 17
# 1                           11                 11
# 2                         1000               1000
# 3                         1239               1239

# %%
df_2017.reset_index(drop=True)
# Out:
#   Dependência Administrativa Total de Escolas Escolas com Água  \
# 0                    Federal               17               17
# 1                   Estadual               10               10
# 2                  Municipal             1007             1007
# 3                 Particular             1251             1247
#
#   Escolas com Energia Elétrica Escolas com Esgoto
# 0                           17                 17
# 1                           10                 10
# 2                         1007               1007
# 3                         1251               1251

# %%
df_2018.reset_index(drop=True)
# Out:
#   Dependência Administrativa Total de Escolas Escolas com Água  \
# 0                    Federal               15               15
# 1                   Estadual                9                9
# 2                  Municipal              992              992
# 3                 Particular             1268             1263
#
#   Escolas com Energia Elétrica Escolas com Esgoto
# 0                           15                 15
# 1                            9                  9
# 2                          992                992
# 3                         1268               1268

# %%
df_2019.reset_index(drop=True)
# Out:
#   Dependência Administrativa Total de Escolas Escolas com Água  \
# 0                    Federal               16               16
# 1                   Estadual                9                9
# 2                  Municipal              992              992
# 3                 Particular             1268             1260
#
#   Escolas com Energia Elétrica Escolas com Esgoto
# 0                           16                 16
# 1                            9                  9
# 2                          992                992
# 3                         1268               1267

# %%
df_2020.reset_index(drop=True)
# Out:
#   Dependência Administrativa Total de Escolas Escolas com Água  \
# 0                    Federal               15               15
# 1                   Estadual                8                8
# 2                  Municipal              991              991
# 3                 Particular             1235             1225
#
#   Escolas com Energia Elétrica Escolas com Esgoto
# 0                           15                 15
# 1                            8                  8
# 2                          991                991
# 3                         1235               1234

# %%
df_5=pd.read_excel('data/1817.xls',sheet_name='T 1817_4')

# %%
df_5
# Out:
#                                              DATA.RIO        Unnamed: 1  \
# 0                                                 NaN               NaN
# 1   Tabela 1817 - Ensino fundamental - Número de e...               NaN
# 2                                                 NaN               NaN
# 3                          Dependência Administrativa  Total de Escolas
# 4                                                 NaN               NaN
# 5                                                2021               NaN
# 6                                             Federal                17
# 7                                            Estadual                 9
# 8                                           Municipal              1005
# 9                                          Particular              1258
# 10                                               2022               NaN
# 11                                            Federal                17
# ...

# %%
df_5.rename(columns={"DATA.RIO":"Dependência Administrativa"},inplace=True)

# %%
df_5.rename(columns={"Unnamed: 1":"Total de Escolas"},inplace=True)

# %%
df_5.rename(columns={"Unnamed: 2":"Escolas com Água"},inplace=True)

# %%
df_5.rename(columns={"Unnamed: 3":"Escolas com Energia Elétrica"},inplace=True)

# %%
df_5.rename(columns={"Unnamed: 4":"Escolas com Esgoto"},inplace=True)

# %%
df_filtrado_4=df_5.drop(index=[0,1,2,3,4,15,16,17]).reset_index(drop=True)

# %%
df_filtrado_4
# Out:
#   Dependência Administrativa Total de Escolas Escolas com Água  \
# 0                       2021              NaN              NaN
# 1                    Federal               17               17
# 2                   Estadual                9                9
# 3                  Municipal             1005             1005
# 4                 Particular             1258             1247
# 5                       2022              NaN              NaN
# 6                    Federal               17               17
# 7                   Estadual                9                9
# 8                  Municipal             1005             1005
# 9                 Particular             1270             1261
#
#   Escolas com Energia Elétrica Escolas com Esgoto
# 0                          NaN                NaN
# 1                           17                 17
# 2                            9                  9
# 3                         1005               1005
# ...

# %%
df_2021=df_filtrado_4.loc[1:4]
df_2022=df_filtrado_4.loc[6:9]

# %%
df_2021.reset_index(drop=True)
# Out:
#   Dependência Administrativa Total de Escolas Escolas com Água  \
# 0                    Federal               17               17
# 1                   Estadual                9                9
# 2                  Municipal             1005             1005
# 3                 Particular             1258             1247
#
#   Escolas com Energia Elétrica Escolas com Esgoto
# 0                           17                 17
# 1                            9                  9
# 2                         1005               1005
# 3                         1258               1256

# %%
df_2022.reset_index(drop=True)
# Out:
#   Dependência Administrativa Total de Escolas Escolas com Água  \
# 0                    Federal               17               17
# 1                   Estadual                9                9
# 2                  Municipal             1005             1005
# 3                 Particular             1270             1261
#
#   Escolas com Energia Elétrica Escolas com Esgoto
# 0                           17                 17
# 1                            9                  9
# 2                         1005               1005
# 3                         1270               1268

# %%
all_datas=pd.concat([df_filtrado,df_filtrado_2,df_filtrado_3,df_filtrado_4]).reset_index(drop=True)

# %%
all_datas
# Out:
#     Dependência Administrativa Total de Escolas Escolas com Água  \
# 0                         2000              NaN              NaN
# 1                      Federal               13               13
# 2                     Estadual              136              136
# 3                    Municipal              953              953
# 4                   Particular             1284             1284
# ..                         ...              ...              ...
# 110                       2022              NaN              NaN
# 111                    Federal               17               17
# 112                   Estadual                9                9
# 113                  Municipal             1005             1005
# 114                 Particular             1270             1261
#
#     Escolas com Energia Elétrica Escolas com Esgoto
# 0                            NaN                NaN
# 1                             13                 13
# ...

# %%
df2_1=pd.read_excel('data/1818.xls',sheet_name='T 1818_1')

# %%
df2_1.rename(columns={"DATA.RIO":"Dependência Administrativa"},inplace=True)

# %%
df2_1.rename(columns={"Unnamed: 1":"Total de Escolas"},inplace=True)

# %%
df2_1.rename(columns={"Unnamed: 2":"Escolas c/ Biblioteca"},inplace=True)

# %%
df2_1.rename(columns={"Unnamed: 3":"Escolas c/ Laboratorio de Informatica"},inplace=True)

# %%
df2_1.rename(columns={"Unnamed: 4":"Escolas c/ Laboratorio de Ciencias"},inplace=True)

# %%
df2_1.rename(columns={"Unnamed: 5":"Escolas c/ Quadras de Esportes"},inplace=True)

# %%
df2_1.rename(columns={"Unnamed: 6":"Escolas c/ Sala TV/Video"},inplace=True)

# %%
df2_1.rename(columns={"Unnamed: 7":"Escolas c/ Sala TV/Video/Parabolica"},inplace=True)

# %%
df2_1.rename(columns={"Unnamed: 8":"Escolas c/ Micro computadores"},inplace=True)

# %%
df2_1.rename(columns={"Unnamed: 9":"Escolas c/ acesso a internet"},inplace=True)

# %%
df2_filtrado=df2_1.drop([0,1,2,3,4,40,41,42,43,44,45])

# %%
df2_filtrado
# Out:
#    Dependência Administrativa Total de Escolas Escolas c/ Biblioteca  \
# 5                        2000              NaN                   NaN
# 6                     Federal               13                    13
# 7                    Estadual              136                    71
# 8                   Municipal              953                   848
# 9                  Particular             1284                   955
# 10                       2001              NaN                   NaN
# 11                    Federal               13                    13
# 12                   Estadual              123                    60
# 13                  Municipal              950                   343
# 14                 Particular             1330                   977
# 15                       2002              NaN                   NaN
# 16                    Federal               13                    13
# 17                   Estadual              117                    64
# ...

# %%
df2_2=pd.read_excel('data/1818.xls',sheet_name='T 1818_2')

# %%
df2_2.rename(columns={"DATA.RIO":"Dependência Administrativa"},inplace=True)

# %%
df2_2.rename(columns={"Unnamed: 1":"Total de Escolas"},inplace=True)

# %%
df2_2.rename(columns={"Unnamed: 2":"Escolas c/ Biblioteca"},inplace=True)

# %%
df2_2.rename(columns={"Unnamed: 3":"Escolas c/ Laboratorio de Informatica"},inplace=True)

# %%
df2_2.rename(columns={"Unnamed: 4":"Escolas c/ Laboratorio de Ciencias"},inplace=True)

# %%
df2_2.rename(columns={"Unnamed: 5":"Escolas c/ Quadras de Esportes"},inplace=True)

# %%
df2_2.rename(columns={"Unnamed: 6":"Escolas c/ Sala TV/Video"},inplace=True)

# %%
df2_2.rename(columns={"Unnamed: 7":"Escolas c/ Sala TV/Video/Parabolica"},inplace=True)

# %%
df2_2.rename(columns={"Unnamed: 8":"Escolas c/ Micro computadores"},inplace=True)

# %%
df2_2.rename(columns={"Unnamed: 9":"Escolas c/ acesso a internet"},inplace=True)

# %%
df2_filtrado_2=df2_2.drop([0,1,2,3,4,40,41,42])

# %%
df2_filtrado_2
# Out:
#    Dependência Administrativa Total de Escolas Escolas c/ Biblioteca  \
# 5                        2007              NaN                   NaN
# 6                     Federal               15                    15
# 7                    Estadual               89                    55
# 8                   Municipal              997                   807
# 9                  Particular              649                   475
# 10                       2008              NaN                   NaN
# 11                    Federal               15                    15
# 12                   Estadual               84                    55
# 13                  Municipal              993                   920
# 14                 Particular             1107                   864
# 15                       2009              NaN                   NaN
# 16                    Federal               15                    13
# 17                   Estadual               77                    56
# ...

# %%
df2_3=pd.read_excel('data/1818.xls',sheet_name='T 1818_3')

# %%
df2_3.rename(columns={"DATA.RIO":"Dependência Administrativa"},inplace=True)

# %%
df2_3.rename(columns={"Unnamed: 1":"Total de Escolas"},inplace=True)

# %%
df2_3.rename(columns={"Unnamed: 2":"Escolas c/ Biblioteca"},inplace=True)

# %%
df2_3.rename(columns={"Unnamed: 3":"Escolas c/ Laboratorio de Informatica"},inplace=True)

# %%
df2_3.rename(columns={"Unnamed: 4":"Escolas c/ Laboratorio de Ciencias"},inplace=True)

# %%
df2_3.rename(columns={"Unnamed: 5":"Escolas c/ Quadras de Esportes"},inplace=True)

# %%
df2_3.rename(columns={"Unnamed: 6":"Escolas c/ Sala TV/Video"},inplace=True)

# %%
df2_3.rename(columns={"Unnamed: 7":"Escolas c/ Sala TV/Video/Parabolica"},inplace=True)

# %%
df2_3.rename(columns={"Unnamed: 8":"Escolas c/ Micro computadores"},inplace=True)

# %%
df2_3.rename(columns={"Unnamed: 9":"Escolas c/ acesso a internet"},inplace=True)

# %%
df2_filtrado_3=df2_3.drop([0,1,2,3,4,40,41,42])

# %%
df2_filtrado_3
# Out:
#    Dependência Administrativa Total de Escolas Escolas c/ Biblioteca  \
# 5                        2014              NaN                   NaN
# 6                     Federal               17                    16
# 7                    Estadual               45                    35
# 8                   Municipal              996                   704
# 9                  Particular             1352                   882
# 10                       2015              NaN                   NaN
# 11                    Federal               17                    15
# 12                   Estadual               12                     9
# 13                  Municipal              991                   864
# 14                 Particular             1246                   839
# 15                       2016              NaN                   NaN
# 16                    Federal               17                    15
# 17                   Estadual               11                    10
# ...

# %%
df2_4=pd.read_excel('data/1818.xls',sheet_name='T 1818_4')

# %%
df2_4.rename(columns={"DATA.RIO":"Dependência Administrativa"},inplace=True)

# %%
df2_4.rename(columns={"Unnamed: 1":"Total de Escolas"},inplace=True)

# %%
df2_4.rename(columns={"Unnamed: 2":"Escolas c/ Biblioteca"},inplace=True)

# %%
df2_4.rename(columns={"Unnamed: 3":"Escolas c/ Laboratorio de Informatica"},inplace=True)

# %%
df2_4.rename(columns={"Unnamed: 4":"Escolas c/ Laboratorio de Ciencias"},inplace=True)

# %%
df2_4.rename(columns={"Unnamed: 5":"Escolas c/ Quadras de Esportes"},inplace=True)

# %%
df2_4.rename(columns={"Unnamed: 6":"Escolas c/ Sala TV/Video"},inplace=True)

# %%
df2_4.rename(columns={"Unnamed: 7":"Escolas c/ Sala TV/Video/Parabolica"},inplace=True)

# %%
df2_4.rename(columns={"Unnamed: 8":"Escolas c/ Micro computadores"},inplace=True)

# %%
df2_4.rename(columns={"Unnamed: 9":"Escolas c/ acesso a internet"},inplace=True)

# %%
df2_filtrado_4=df2_4.drop([0,1,2,3,4,15,16,17])

# %%
df2_filtrado_4
# Out:
#    Dependência Administrativa Total de Escolas Escolas c/ Biblioteca  \
# 5                        2021              NaN                   NaN
# 6                     Federal               17                    17
# 7                    Estadual                9                     6
# 8                   Municipal             1005                   425
# 9                  Particular             1258                   772
# 10                       2021              NaN                   NaN
# 11                    Federal               17                    17
# 12                   Estadual                9                     6
# 13                  Municipal             1005                   397
# 14                 Particular             1270                   771
#
#    Escolas c/ Laboratorio de Informatica Escolas c/ Laboratorio de Ciencias  \
# 5                                    NaN                                NaN
# ...

# %%
all_data_2=pd.concat([df2_filtrado,df2_filtrado_2,df2_filtrado_3,df2_filtrado_4]).reset_index(drop=True)

# %%
all_data_2
# Out:
#     Dependência Administrativa Total de Escolas Escolas c/ Biblioteca  \
# 0                         2000              NaN                   NaN
# 1                      Federal               13                    13
# 2                     Estadual              136                    71
# 3                    Municipal              953                   848
# 4                   Particular             1284                   955
# 5                         2001              NaN                   NaN
# 6                      Federal               13                    13
# 7                     Estadual              123                    60
# 8                    Municipal              950                   343
# 9                   Particular             1330                   977
# 10                        2002              NaN                   NaN
# 11                     Federal               13                    13
# ...

# %%
a=1
b=5

for data in range(23):
    ano=2000+data
    exec(f'df_2_{ano}=all_data_2.iloc[{a}:{b}]')
    a=a+5
    b=b+5

# %%
df_2_2022
# Out:
#     Dependência Administrativa Total de Escolas Escolas c/ Biblioteca  \
# 111                    Federal               17                    17
# 112                   Estadual                9                     6
# 113                  Municipal             1005                   397
# 114                 Particular             1270                   771
#
#     Escolas c/ Laboratorio de Informatica Escolas c/ Laboratorio de Ciencias  \
# 111                                    17                                 17
# 112                                     5                                  5
# 113                                   624                                211
# 114                                   620                                344
#
#     Escolas c/ Quadras de Esportes Escolas c/ Sala TV/Video  \
# 111                             17                       17
# 112                              6                        8
# ...
